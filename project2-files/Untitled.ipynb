# %%
import pandas as pd
import numpy as np
import requests
import json
from config import API_KEY
from pprint import pprint
from sqlalchemy import create_engine
API_KEY
# Out:
# 'c597e03b5a2c4d0380b0bbba6a23f4aa'

# %%
base_url = "http://lapi.transitchicago.com/api/1.0/ttarrivals.aspx"
stop_data = pd.read_csv("list_of_stops.csv") 
stop_data
# Out:
#      STOP_ID DIRECTION_ID                                     STOP_NAME  \
# 0      30162            W                      18th (54th/Cermak-bound)
# 1      30161            E                             18th (Loop-bound)
# 2      30022            N                      35th/Archer (Loop-bound)
# 3      30023            S                    35th/Archer (Midway-bound)
# 4      30214            S               35-Bronzeville-IIT (63rd-bound)
# 5      30213            N             35-Bronzeville-IIT (Harlem-bound)
# 6      30246            S                             43rd (63rd-bound)
# 7      30245            N                           43rd (Harlem-bound)
# 8      30025            S                             51st (63rd-bound)
# 9      30024            N                           51st (Harlem-bound)
# 10     30113            E                      54th/Cermak (Loop-bound)
# 11     30114            W                54th/Cermak (Terminal arrival)
# ...

# %%
for x in stop_data['STOP_ID']:
    query_url = f"http://lapi.transitchicago.com/api/1.0/ttarrivals.aspx?key={API_KEY}&max=1&stpid={x}&outputType=JSON"
    response = requests.get(query_url)
    pprint(response.json())
# Out:
# {'ctatt': {'errCd': '0',
#            'errNm': None,
#            'eta': [{'arrT': '2019-11-12T21:38:48',
#                     'destNm': '54th/Cermak',
#                     'destSt': '30114',
#                     'flags': None,
#                     'heading': '178',
#                     'isApp': '1',
#                     'isDly': '0',
#                     'isFlt': '0',
#                     'isSch': '0',
#                     'lat': '41.87018',
#                     'lon': '-87.66951',
#                     'prdt': '2019-11-12T21:37:48',
#                     'rn': '318',
#                     'rt': 'Pink',
#                     'staId': '40830',
#                     'staNm': '18th',
#                     'stpDe': 'Service toward 54th/Cermak',
#                     'stpId': '30162',
#                     'trDr': '5'}],
#            'tmst': '2019-11-12T21:38:15'}}
# {'ctatt': {'errCd': '0',
#            'errNm': None,
#            'eta': [{'arrT': '2019-11-12T21:43:48',
# ...

# %%
data = response.json()

# %%
print(data)
# Out:
# {'ctatt': {'tmst': '2019-11-12T21:18:38', 'errCd': '0', 'errNm': None, 'eta': [{'staId': '40170', 'stpId': '30032', 'staNm': 'Ashland', 'stpDe': 'Service toward Loop or 63rd St', 'rn': '317', 'rt': 'Pink', 'destSt': '30114', 'destNm': 'Loop', 'trDr': '5', 'prdt': '2019-11-12T21:17:55', 'arrT': '2019-11-12T21:22:55', 'isApp': '0', 'isSch': '0', 'isDly': '0', 'isFlt': '0', 'flags': None, 'lat': '41.85791', 'lon': '-87.66916', 'heading': '358'}]}}

# %%
data["ctatt"]["eta"][0]['stpId']
# Out:
# '30032'
